# %%
from IPython.display import clear_output
import pandas as pd 
import subprocess #run R code from subprocess
import numpy as np
from os import listdir # get dir list
from os.path import isfile, join # get dir list

import time
import concurrent.futures

# %%
def getFolderFilesList(path):
    return [filename for filename in listdir(path) if isfile(join(path, filename))]

def runNoiseFilter (file, count):
    # subprocess.call ("Rscript --vanilla HARF.r " + file, shell=True)
    # !{"Rscript --vanilla AENN.r " + file}

# %%
datasetsFilesNames = getFolderFilesList("Datasets")
datasetsFilesNames
# Out:
# ['1064_ar6.csv.zip',
#  '911_fri_c2_250_5.csv.zip',
#  '787_witmer_census_1980.csv.zip',
#  '886_no2.csv.zip',
#  '1442_MegaWatt1.csv.zip',
#  '983_cmc.csv.zip',
#  '976_JapaneseVowels.csv.zip',
#  '1490_planning-relax.csv.zip',
#  '40683_postoperative-patient-data.csv.zip',
#  '1463_blogger.csv.zip',
#  '895_chscase_geyser1.csv.zip',
#  '827_disclosure_x_noise.csv.zip',
#  '942_chscase_health.csv.zip',
#  '888_fri_c0_500_50.csv.zip',
#  '868_fri_c4_100_25.csv.zip',
#  '996_prnn_fglass.csv.zip',
#  '904_fri_c0_1000_50.csv.zip',
#  '943_fri_c0_500_10.csv.zip',
#  '1167_pc1_req.csv.zip',
#  '951_arsenic-male-lung.csv.zip',
#  '1015_confidence.csv.zip',
#  '50_tic-tac-toe.csv.zip',
#  '805_fri_c4_500_50.csv.zip',
#  '1506_thoracic-surgery.csv.zip',
#  '43957_house_16H.csv.zip',
#  '824_fri_c1_500_10.csv.zip',
#  '813_fri_c3_1000_5.csv.zip',
#  '764_analcatdata_apnea3.csv.zip',
#  '40710_cleve.csv.zip',
#  '758_analcatdata_election2000.csv.zip',
#  '461_analcatdata_creditscore.csv.zip',
#  '838_fri_c4_500_25.csv.zip',
#  '789_fri_c1_100_10.csv.zip',
#  '724_analcatdata_vineyard.csv.zip',
#  '871_pollen.csv.zip',
#  '41156_ada.csv.zip',
#  '841_stock.csv.zip',
#  '1066_kc1-binary.csv.zip',
#  '1453_PieChart3.csv.zip',
#  '879_fri_c2_500_25.csv.zip',
#  '1014_analcatdata_dmft.csv.zip',
#  '947_arsenic-male-bladder.csv.zip',
#  '1067_kc1.csv.zip',
#  '715_fri_c3_1000_25.csv.zip',
#  '979_waveform-5000.csv.zip',
#  '958_segment.csv.zip',
#  '1063_kc2.csv.zip',
#  '923_visualizing_soil.csv.zip',
#  '980_optdigits.csv.zip',
#  '1447_CastMetal1.csv.zip',
#  '893_visualizing_hamster.csv.zip',
#  '1487_ozone-level-8hr.csv.zip',
#  '459_analcatdata_asbestos.csv.zip',
#  '1471_eeg-eye-state.csv.zip',
#  '4154_CreditCardSubset.csv.zip',
#  '749_fri_c3_500_5.csv.zip',
#  '853_boston.csv.zip',
#  '714_fruitfly.csv.zip',
#  '850_fri_c0_100_50.csv.zip',
#  '1011_ecoli.csv.zip',
#  '41005_jungle_chess_2pcs_endgame_rat_rat.csv.zip',
#  '908_chscase_census3.csv.zip',
#  '740_fri_c3_1000_10.csv.zip',
#  '900_chscase_census6.csv.zip',
#  '913_fri_c2_1000_10.csv.zip',
#  '40706_parity5_plus_5.csv.zip',
#  '1441_KungChi3.csv.zip',
#  '965_zoo.csv.zip',
#  '41007_jungle_chess_2pcs_endgame_lion_lion.csv.zip',
#  '1446_CostaMadre1.csv.zip',
#  '890_cloud.csv.zip',
#  '41945_ilpd-numeric.csv.zip',
#  '40647_GAMETES_Epistasis_2-Way_20atts_0.4H_EDM-1_1.csv.zip',
#  '794_fri_c2_250_25.csv.zip',
#  '774_disclosure_x_bias.csv.zip',
#  '803_delta_ailerons.csv.zip',
#  '792_fri_c2_500_5.csv.zip',
#  '3_kr-vs-kp.csv.zip',
#  '479_analcatdata_cyyoung9302.csv.zip',
#  '1019_pendigits.csv.zip',
#  '53_heart-statlog.csv.zip',
#  '790_elusage.csv.zip',
#  '42192_compas-two-years.csv.zip',
#  '778_bodyfat.csv.zip',
#  '977_letter.csv.zip',
#  '44_spambase.csv.zip',
#  '759_analcatdata_olympic2000.csv.zip',
#  '44089_credit.csv.zip',
#  '1412_lungcancer_GSE31210.csv.zip',
#  '1048_jEdit_4.2_4.3.csv.zip',
#  '40681_mux6.csv.zip',
#  '1511_wholesale-customers.csv.zip',
#  '765_analcatdata_apnea2.csv.zip',
#  '1462_banknote-authentication.csv.zip',
#  '756_autoPrice.csv.zip',
#  '716_fri_c3_100_50.csv.zip',
#  '962_mfeat-morphological.csv.zip',
#  '969_iris.csv.zip',
#  '1056_mc1.csv.zip',
#  '754_fri_c0_100_5.csv.zip',
#  '720_abalone.csv.zip',
#  '40704_Titanic.csv.zip',
#  '43_haberman.csv.zip',
#  '846_elevators.csv.zip',
#  '376_SyskillWebert-Sheep.csv.zip',
#  '1005_glass.csv.zip',
#  '876_fri_c1_100_50.csv.zip',
#  '799_fri_c0_1000_5.csv.zip',
#  '806_fri_c3_1000_50.csv.zip',
#  '751_fri_c4_1000_10.csv.zip',
#  '43947_KDDCup09_upselling.csv.zip',
#  '1054_mc2.csv.zip',
#  '446_prnn_crabs.csv.zip',
#  '767_analcatdata_apnea1.csv.zip',
#  '346_aids.csv.zip',
#  '855_fri_c4_500_10.csv.zip',
#  '1452_PieChart2.csv.zip',
#  '804_hutsof99_logis.csv.zip',
#  '746_fri_c1_250_25.csv.zip',
#  '970_analcatdata_authorship.csv.zip',
#  '40589_emotions.csv.zip',
#  '910_fri_c1_1000_10.csv.zip',
#  '1495_qualitative-bankruptcy.csv.zip',
#  '811_rmftsa_ctoarrivals.csv.zip',
#  '748_analcatdata_wildcat.csv.zip',
#  '683_sleuth_ex2015.csv.zip',
#  '1068_pc1.csv.zip',
#  '909_chscase_census2.csv.zip',
#  '807_kin8nm.csv.zip',
#  '4534_PhishingWebsites.csv.zip',
#  '1049_pc4.csv.zip',
#  '1006_lymph.csv.zip',
#  '870_fri_c1_500_5.csv.zip',
#  '476_analcatdata_bankruptcy.csv.zip',
#  '829_fri_c1_100_5.csv.zip',
#  '808_fri_c0_100_10.csv.zip',
#  '1450_MindCave2.csv.zip',
#  '743_fri_c1_1000_5.csv.zip',
#  '721_pwLinear.csv.zip',
#  '773_fri_c0_250_25.csv.zip',
#  '1071_mw1.csv.zip',
#  '863_fri_c4_250_10.csv.zip',
#  '1488_parkinsons.csv.zip',
#  '752_puma32H.csv.zip',
#  '37_diabetes.csv.zip',
#  '991_car.csv.zip',
#  '878_fri_c4_100_10.csv.zip',
#  '333_monks-problems-1.csv.zip',
#  '1504_steel-plates-fault.csv.zip',
#  '40701_churn.csv.zip',
#  '761_cpu_act.csv.zip',
#  '931_disclosure_z.csv.zip',
#  '1025_analcatdata_germangss.csv.zip',
#  '845_fri_c0_1000_10.csv.zip',
#  '780_rabe_265.csv.zip',
#  '747_servo.csv.zip',
#  '796_cpu.csv.zip',
#  '885_transplant.csv.zip',
#  '40713_dis.csv.zip',
#  '916_fri_c3_100_5.csv.zip',
#  '762_fri_c2_100_10.csv.zip',
#  '896_fri_c3_500_25.csv.zip',
#  '772_quake.csv.zip',
#  '1012_flags.csv.zip',
#  '335_monks-problems-3.csv.zip',
#  '771_analcatdata_michiganacc.csv.zip',
#  '1021_page-blocks.csv.zip',
#  '44162_compass.csv.zip',
#  '775_fri_c2_100_25.csv.zip',
#  '1460_banana.csv.zip',
#  '766_fri_c1_500_50.csv.zip',
#  '907_chscase_census4.csv.zip',
#  '770_strikes.csv.zip',
#  '877_fri_c2_250_50.csv.zip',
#  '859_analcatdata_gviolence.csv.zip',
#  '830_fri_c2_250_10.csv.zip',
#  '849_fri_c0_1000_25.csv.zip',
#  '832_fri_c3_250_25.csv.zip',
#  '800_pyrim.csv.zip',
#  '776_fri_c0_250_5.csv.zip',
#  '937_fri_c3_500_50.csv.zip',
#  '801_chscase_funds.csv.zip',
#  '932_fri_c4_100_50.csv.zip',
#  '1065_kc3.csv.zip',
#  '40900_Satellite.csv.zip',
#  '917_fri_c1_1000_25.csv.zip',
#  '1075_datatrieve.csv.zip',
#  '723_fri_c4_1000_25.csv.zip',
#  '994_vehicle.csv.zip',
#  '728_analcatdata_supreme.csv.zip',
#  '784_newton_hema.csv.zip',
#  '837_fri_c1_1000_50.csv.zip',
#  '726_fri_c2_100_5.csv.zip',
#  '782_rabe_266.csv.zip',
#  '717_rmftsa_ladata.csv.zip',
#  '753_wisconsin.csv.zip',
#  '987_collins.csv.zip',
#  '955_tae.csv.zip',
#  '40693_xd6.csv.zip',
#  '40999_jungle_chess_2pcs_endgame_elephant_elephant.csv.zip',
#  '783_fri_c3_100_10.csv.zip',
#  '950_arsenic-female-lung.csv.zip',
#  '946_visualizing_ethanol.csv.zip',
#  '311_oil_spill.csv.zip',
#  '40_sonar.csv.zip',
#  '1060_ar3.csv.zip',
#  '722_pol.csv.zip',
#  '737_space_ga.csv.zip',
#  '1013_analcatdata_challenger.csv.zip',
#  '1443_PizzaCutter1.csv.zip',
#  '1009_white-clover.csv.zip',
#  '1455_acute-inflammations.csv.zip',
#  '826_sensory.csv.zip',
#  '1489_phoneme.csv.zip',
#  '820_chatfield_4.csv.zip',
#  '1449_MeanWhile1.csv.zip',
#  '450_analcatdata_lawsuit.csv.zip',
#  '933_fri_c4_250_25.csv.zip',
#  '1059_ar1.csv.zip',
#  '1451_PieChart1.csv.zip',
#  '41976_TuningSVMs.csv.zip',
#  '814_chscase_vine2.csv.zip',
#  '1121_badges2.csv.zip',
#  '797_fri_c4_1000_50.csv.zip',
#  '755_sleuth_ex1605.csv.zip',
#  '43949_rl.csv.zip',
#  '880_mu284.csv.zip',
#  '922_fri_c2_100_50.csv.zip',
#  '874_rabe_131.csv.zip',
#  '40649_GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_50_EDM-2_001.csv.zip',
#  '40981_Australian.csv.zip',
#  '825_boston_corrected.csv.zip',
#  '884_fri_c0_500_5.csv.zip',
#  '1069_pc2.csv.zip',
#  '865_analcatdata_neavote.csv.zip',
#  '44149_Heart_disease_prediction_20.csv.zip',
#  '23499_breast-cancer-dropped-missing-attributes-values.csv.zip',
#  '444_analcatdata_boxing2.csv.zip',
#  '464_prnn_synth.csv.zip',
#  '936_fri_c3_500_10.csv.zip',
#  '925_visualizing_galaxy.csv.zip',
#  '682_sleuth_ex2016.csv.zip',
#  '730_fri_c1_250_5.csv.zip',
#  '1507_twonorm.csv.zip',
#  '1448_KnuggetChase3.csv.zip',
#  '1498_sa-heart.csv.zip',
#  '1016_vowel.csv.zip',
#  '44097_credit-g_copy.csv.zip',
#  '1046_mozilla4.csv.zip',
#  '926_fri_c0_500_25.csv.zip',
#  '745_auto_price.csv.zip',
#  '40705_tokyo1.csv.zip',
#  '41946_Sick_numeric.csv.zip',
#  '1480_ilpd.csv.zip',
#  '769_fri_c1_250_50.csv.zip',
#  '795_disclosure_x_tampered.csv.zip',
#  '974_hayes-roth.csv.zip',
#  '448_analcatdata_boxing1.csv.zip',
#  '920_fri_c2_500_50.csv.zip',
#  '334_monks-problems-2.csv.zip',
#  '43892_national-longitudinal-survey-binary.csv.zip',
#  '732_fri_c0_250_50.csv.zip',
#  '997_balance-scale.csv.zip',
#  '892_sleuth_case1201.csv.zip',
#  '1510_wdbc.csv.zip',
#  '959_nursery.csv.zip',
#  '735_cpu_small.csv.zip',
#  '734_ailerons.csv.zip',
#  '833_bank32nh.csv.zip',
#  '1444_PizzaCutter3.csv.zip',
#  '935_fri_c1_250_10.csv.zip',
#  '915_plasma_retinol.csv.zip',
#  '768_fri_c3_100_25.csv.zip',
#  '973_wine.csv.zip',
#  '941_lowbwt.csv.zip',
#  '1558_bank-marketing.csv.zip',
#  '4329_thoracic_surgery.csv.zip',
#  '472_lupus.csv.zip',
#  '1055_cm1_req.csv.zip',
#  '1120_MagicTelescope.csv.zip',
#  '918_fri_c4_250_50.csv.zip',
#  '779_fri_c1_500_25.csv.zip',
#  '1020_mfeat-karhunen.csv.zip',
#  '40983_wilt.csv.zip',
#  '41538_conference_attendance.csv.zip',
#  '467_analcatdata_japansolvent.csv.zip',
#  '40680_mofn-3-7-10.csv.zip',
#  '971_mfeat-fourier.csv.zip',
#  '40648_GAMETES_Epistasis_3-Way_20atts_0.2H_EDM-1_1.csv.zip',
#  '891_sleuth_case1202.csv.zip',
#  '929_rabe_176.csv.zip',
#  '465_analcatdata_cyyoung8092.csv.zip',
#  '902_sleuth_case2002.csv.zip',
#  '847_wind.csv.zip',
#  '934_socmob.csv.zip',
#  '741_rmftsa_sleepdata.csv.zip',
#  '59_ionosphere.csv.zip',
#  '819_delta_elevators.csv.zip',
#  '337_SPECTF.csv.zip',
#  '1004_synthetic_control.csv.zip',
#  '43946_eye_movements.csv.zip',
#  '921_analcatdata_seropositive.csv.zip',
#  '44098_credit-g_reproduced_1.csv.zip',
#  '949_arsenic-female-bladder.csv.zip',
#  '788_triazines.csv.zip',
#  '945_kidney.csv.zip',
#  '1496_ringnorm.csv.zip',
#  '887_mbagrade.csv.zip',
#  '40702_solar-flare.csv.zip',
#  '40669_corral.csv.zip',
#  '867_visualizing_livestock.csv.zip',
#  '815_chscase_vine1.csv.zip',
#  '1473_fertility.csv.zip',
#  '44095_spambase_reproduced.csv.zip',
#  '1524_vertebra-column.csv.zip',
#  '725_bank8FM.csv.zip',
#  '882_pollution.csv.zip',
#  '818_diggle_table_a2.csv.zip',
#  '31_credit-g.csv.zip',
#  '40690_threeOf9.csv.zip',
#  '1464_blood-transfusion-service-center.csv.zip',
#  '1494_qsar-biodeg.csv.zip',
#  '731_baskball.csv.zip',
#  '336_SPECT.csv.zip',
#  '713_vineyard.csv.zip',
#  '744_fri_c3_250_5.csv.zip',
#  '866_fri_c2_1000_50.csv.zip',
#  '736_visualizing_environmental.csv.zip',
#  '1050_pc3.csv.zip',
#  '40650_GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_75_EDM-2_001.csv.zip',
#  '463_backache.csv.zip',
#  '1061_ar4.csv.zip',
#  '869_fri_c2_500_10.csv.zip',
#  '40646_GAMETES_Epistasis_2-Way_20atts_0.1H_EDM-1_1.csv.zip',
#  '875_analcatdata_chlamydia.csv.zip',
#  '906_chscase_census5.csv.zip',
#  '912_fri_c2_1000_5.csv.zip',
#  '873_fri_c3_250_50.csv.zip',
#  '793_fri_c3_250_10.csv.zip',
#  '860_vinnie.csv.zip',
#  '988_fl2000.csv.zip',
#  '1026_grub-damage.csv.zip',
#  '310_mammography.csv.zip',
#  '889_fri_c0_100_25.csv.zip',
#  '733_machine_cpu.csv.zip',
#  '719_veteran.csv.zip',
#  '1045_kc1-top5.csv.zip',
#  '1073_jEdit_4.0_4.2.csv.zip',
#  '42665_ricci_vs_destefano.csv.zip',
#  '816_puma8NH.csv.zip',
#  '894_rabe_148.csv.zip',
#  '903_fri_c2_1000_25.csv.zip',
#  '750_pm10.csv.zip',
#  '1467_climate-model-simulation-crashes.csv.zip',
#  '812_fri_c1_100_25.csv.zip',
#  '763_fri_c0_250_10.csv.zip',
#  '995_mfeat-zernike.csv.zip',
#  '1547_autoUniv-au1-1000.csv.zip']
