# %%
from IPython.display import clear_output
import pandas as pd 
import subprocess #run R code from subprocess
import numpy as np
from os import listdir # get dir list
from os.path import isfile, join # get dir list

import time
import concurrent.futures

# %%
def getFolderFilesList(path):
    return [filename for filename in listdir(path) if isfile(join(path, filename))]

def runNoiseFilter (file, count):
    # subprocess.call ("Rscript --vanilla HARF.r " + file, shell=True)
    # !{"Rscript --vanilla ORBoost.r " + file}

# %%
# datasetsFilesNames = getFolderFilesList("NoisyDatasets")
# smallSet = datasetsFilesNames
# start = time.perf_counter()
# count = 0
# # with concurrent.futures.ProcessPoolExecutor(4) as executor:
# #     executor.map(runNoiseFilter, smallSet)

# with concurrent.futures.ProcessPoolExecutor(20) as executor:
# #                 results = executor.map(runMFE, smallSet)
#     results = [executor.submit(runNoiseFilter, dataset, count) for dataset in smallSet]
#     for s in concurrent.futures.as_completed(results):
#         clear_output(wait=True)
#         count+=1
#         finish = time.perf_counter()
#         print ("exec " + str(count) + " / " + str(len(datasetsFilesNames)))
#         print(f'tempo de execução: {int((finish-start)/60)} min {int((finish-start)%60)} s')
# finish = time.perf_counter()
# print(f'terminou em: {int((finish-start)/60)} min {int((finish-start)%60)} s')
# Out:
# exec 11122 / 11160
# tempo de execução: 255 min 26 s

# %%
datasetsFilesNames = getFolderFilesList("NoisyDatasets")
smallSet = datasetsFilesNames
start = time.perf_counter()
count = 0
# with concurrent.futures.ProcessPoolExecutor(4) as executor:
#     executor.map(runNoiseFilter, smallSet)

with concurrent.futures.ProcessPoolExecutor(60) as executor:
#                 results = executor.map(runMFE, smallSet)
    results = [executor.submit(runNoiseFilter, dataset, count) for dataset in smallSet]
    for s in concurrent.futures.as_completed(results):
        clear_output(wait=True)
        count+=1
        #finish = time.perf_counter()
        #print ("exec " + str(count) + " / " + str(len(datasetsFilesNames)))
        #print(f'tempo de execução: {int((finish-start)/60)} min {int((finish-start)%60)} s')
finish = time.perf_counter()
print(f'terminou em: {int((finish-start)/60)} min {int((finish-start)%60)} s')
# Out:
# Error : source file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' does not exist
# Error : target file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' already exists
# Error : target file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' already exists
# Error : target file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' already exists
# Error : "~/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv" does not exist
# In addition: Warning message:
# The following package(s) are missing entries in the cache:
#
# 	renv
#
# These packages will need to be reinstalled.
#
# Error : target file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' already exists
# Error : "~/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv" does not exist
# Warning message:
# In file(con, "rb") :
#   cannot open file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv/DESCRIPTION': No such file or directory
# Error in file(con, "rb") : cannot open the connection
# In addition: Warning message:
# In file(con, "rb") :
#   cannot open file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv/DESCRIPTION': No such file or directory
# Error : "~/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv" does not exist
# Error : "~/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv" does not exist
# Warning message:
# The following package(s) are missing entries in the cache:
#
# 	renv
#
# These packages will need to be reinstalled.
#
# Error in file(con, "rb") : cannot open the connection
# In addition: Warning message:
# In file(con, "rb") :
#   cannot open file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv/DESCRIPTION': No such file or directory
# Error : target file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' already exists
# Warning message:
# The following package(s) are missing entries in the cache:
#
# 	renv
#
# These packages will need to be reinstalled.
#
# Error : "~/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv" does not exist
# Error : target file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' already exists
# Error : source file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' does not exist
# Error : target file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' already exists
# In addition: Warning message:
# The following package(s) are missing entries in the cache:
#
# 	renv
#
# These packages will need to be reinstalled.
#
# Error : target file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' already exists
# Error : target file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' already exists
# Error : "~/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv" does not exist
# Error : source file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' does not exist
# Warning message:
# In file(con, "rb") :
#   cannot open file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv/DESCRIPTION': No such file or directory
# Error : "~/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv" does not exist
# Error : target file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' already exists
# In addition: Warning message:
# The following package(s) are missing entries in the cache:
#
# 	renv
#
# These packages will need to be reinstalled.
#
# Error : target file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' already exists
# Warning message:
# In file(con, "rb") :
#   cannot open file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv/DESCRIPTION': No such file or directory
# Error : "~/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv" does not exist
# Error : "~/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv" does not exist
# Error : target file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' already exists
# In addition: Warning message:
# The following package(s) are missing entries in the cache:
#
# 	renv
#
# These packages will need to be reinstalled.
#
# Error : source file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' does not exist
# In addition: Warning message:
# The following package(s) are missing entries in the cache:
#
# 	renv
#
# These packages will need to be reinstalled.
#
# Error : target file '/home/lpfgarcia/pedropio/NoiseSelection/renv/library/R-3.6/x86_64-pc-linux-gnu/renv' already exists

# %%
# len(getFolderFilesList("NoisyDatasets"))
# datasetsFilesNames
datasetsFilesNames = getFolderFilesList("NoisyDatasets")
smallSet = datasetsFilesNames[0:60]
for i in smallSet[0:1]:
    runNoiseFilter(i,0)
# Out:
# Iteration 1: 0 noisy instances removed.
# Iteration 2: 431 noisy instances removed.
# Iteration 3: 0 noisy instances removed.
# Iteration 4: 1 noisy instances removed.
# Iteration 5: 0 noisy instances removed.
# Iteration 6: 0 noisy instances removed.
# Iteration 7: 0 noisy instances removed.
# Iteration 8: 0 noisy instances removed.
# Iteration 9: 17 noisy instances removed.
# Iteration 10: 0 noisy instances removed.
# Iteration 11: 0 noisy instances removed.
# Iteration 12: 0 noisy instances removed.
# Iteration 13: 20 noisy instances removed.
# Iteration 14: 4 noisy instances removed.
# Iteration 15: 0 noisy instances removed.
# Iteration 16: 0 noisy instances removed.
# Iteration 17: 0 noisy instances removed.
# Iteration 18: 2 noisy instances removed.
# Iteration 19: 0 noisy instances removed.
# Iteration 20: 158 noisy instances removed.
# Iteration 1: 0 noisy instances removed.
# Iteration 2: 0 noisy instances removed.
# Iteration 3: 431 noisy instances removed.
# Iteration 4: 0 noisy instances removed.
# Iteration 5: 0 noisy instances removed.
# Iteration 6: 0 noisy instances removed.
# Iteration 7: 1 noisy instances removed.
# Iteration 8: 0 noisy instances removed.
# Iteration 9: 20 noisy instances removed.
# Iteration 10: 0 noisy instances removed.
# Iteration 11: 0 noisy instances removed.
# Iteration 12: 1 noisy instances removed.
# Iteration 13: 21 noisy instances removed.
# Iteration 14: 0 noisy instances removed.
# Iteration 15: 151 noisy instances removed.
# Iteration 16: 12 noisy instances removed.
# Iteration 17: 1387 noisy instances removed.
# Iteration 18: 0 noisy instances removed.
# Iteration 19: 0 noisy instances removed.
# Iteration 20: 0 noisy instances removed.
# Iteration 1: 0 noisy instances removed.
# Iteration 2: 0 noisy instances removed.
# Iteration 3: 0 noisy instances removed.
# Iteration 4: 431 noisy instances removed.
# Iteration 5: 0 noisy instances removed.
# Iteration 6: 0 noisy instances removed.
# Iteration 7: 0 noisy instances removed.
# Iteration 8: 1 noisy instances removed.
# Iteration 9: 0 noisy instances removed.
# Iteration 10: 0 noisy instances removed.
# Iteration 11: 0 noisy instances removed.
# Iteration 12: 185 noisy instances removed.
# Iteration 13: 0 noisy instances removed.
# Iteration 14: 13 noisy instances removed.
# Iteration 15: 29 noisy instances removed.
# Iteration 16: 449 noisy instances removed.
# Iteration 17: 66 noisy instances removed.
# Iteration 18: 141 noisy instances removed.
# Iteration 19: 0 noisy instances removed.
# Iteration 20: 0 noisy instances removed.
# Iteration 1: 0 noisy instances removed.
# Iteration 2: 0 noisy instances removed.
# Iteration 3: 0 noisy instances removed.
# Iteration 4: 0 noisy instances removed.
# Iteration 5: 431 noisy instances removed.
# Iteration 6: 0 noisy instances removed.
# Iteration 7: 0 noisy instances removed.
# Iteration 8: 0 noisy instances removed.
# Iteration 9: 0 noisy instances removed.
# Iteration 10: 1 noisy instances removed.
# Iteration 11: 0 noisy instances removed.
# Iteration 12: 0 noisy instances removed.
# Iteration 13: 205 noisy instances removed.
# Iteration 14: 0 noisy instances removed.
# Iteration 15: 23 noisy instances removed.
# Iteration 16: 156 noisy instances removed.
# Iteration 17: 0 noisy instances removed.
# Iteration 18: 0 noisy instances removed.
# Iteration 19: 77 noisy instances removed.
# Iteration 20: 13 noisy instances removed.

# %%
# runNoiseFilter (datasetsFilesNames[0], 0)
# /home/lpfgarcia/pedropio/NoiseSelection/Rscript
len(getFolderFilesList('NoisyDatasetsAfterFilters/ORBoost-3'))
# Out:
# 10629
